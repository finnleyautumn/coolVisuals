# %% [markdown]
# # Blue Bikes Visuals
# *Finnley Autumn Rogers* | 2024-07-22
#
# Please see README.md for data overview and description of visualization goals.
#
# This notebook is meant to be the container for visualization code and descriptions of the creation process.
#
# ## Data Preprocessing

# %%
import pandas as pd
import numpy as np
import geopandas as gpd

import folium
import matplotlib as mpl

# %%
# read data
bb2019_path = "data/bluebikes_tripdata_2019.csv"
bb2020_path = "data/bluebikes_tripdata_2020.csv"

# %%
# bb2019 = pd.read_csv(bb2019_path, nrows= 200)
bb2020 = pd.read_csv(bb2020_path, nrows= 200)

# %%
bb2020.head(2)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2020-11-01 00:00:18.3990  2020-11-01 00:30:12.2630
# 1          1832  2020-11-01 00:00:34.3330  2020-11-01 00:31:07.2920
#
#    start station id           start station name  start station latitude  \
# 0               186  Congress St at Northern Ave                 42.3481
# 1               186  Congress St at Northern Ave                 42.3481
#
#    start station longitude  end station id             end station name  \
# 0                -71.03764             186  Congress St at Northern Ave
# 1                -71.03764             186  Congress St at Northern Ave
#
#    end station latitude  end station longitude  bikeid  usertype  postal code  \
# 0               42.3481              -71.03764    4896  Customer      11214.0
# 1               42.3481              -71.03764    5630  Customer      11220.0
#
#    year  month  birth year  gender
# 0  2020     11         NaN     NaN
# 1  2020     11         NaN     NaN

# %% [markdown]
# Lets start by plotting all the unique bike stations on a map to get a "lay of the land".

# %%
# get unique stations
stations = bb2020[['start station name', 'start station latitude', 'start station longitude']].drop_duplicates(subset = ['start station name'])

# renaming columns for brevity
stations.columns = ['start_station', 'latitude', 'longitude']

# %%
# make geopandas dataframe for folium
mapping_df = gpd.GeoDataFrame(stations)
mapping_df.head(2)
# Out:
#                          start_station   latitude  longitude
# 0          Congress St at Northern Ave  42.348100 -71.037640
# 3  Harvard Square at Mass Ave/ Dunster  42.373268 -71.118579

# %%
# make folium map
station_map = folium.Map(tiles='OpenStreetMap', zoom_start=20)

# %%
def plotPoint(point):
    '''
    ## plotPoint

    function to add a given point to a folium map

    ### Parameters

    - point (pandas df row): a row containing a latitude and longitude column

    ### Return

    - Boolean: True if plotting was successful, False if an error is raised
    '''

    folium.Marker(location = [point.latitude, point.longitude],
                  popup = point.start_station,
                  icon = folium.Icon(color = 'blue', icon='bicycle', prefix='fa')).add_to(station_map)

# %%
mapping_df.apply(plotPoint, axis = 1)
# Out:
# 0      None
# 3      None
# 4      None
# 5      None
# 7      None
#        ...
# 187    None
# 191    None
# 195    None
# 196    None
# 197    None
# Length: 95, dtype: object

# %%
station_map.fit_bounds(station_map.get_bounds())

# %%
# save map to outputs
station_map.save("outputs/bluebikes_station_locations.html")

# display inline
station_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6615f31586ec067cfc1981a53c976f02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6615f31586ec067cfc1981a53c976f02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6615f31586ec067cfc1981a53c976f02 = L.map(
#                 &quot;map_6615f31586ec067cfc1981a53c976f02&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f06fdacb1ba4fe2fbfd055b4b04f3c46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f06fdacb1ba4fe2fbfd055b4b04f3c46.addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var marker_ecdf3f2ddbd36cc8e8d8a029639b13ce = L.marker(
#                 [42.3481, -71.03764],
#                 {}
#             ).addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var icon_eff453b1f7cf99b1da9d37b94b02b4a5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ecdf3f2ddbd36cc8e8d8a029639b13ce.setIcon(icon_eff453b1f7cf99b1da9d37b94b02b4a5);
#
#
#         var popup_8bfa65e37865cfa6a84ec96cdd82682a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7124bbce359c82e3521328a9cc3b7e34 = $(`&lt;div id=&quot;html_7124bbce359c82e3521328a9cc3b7e34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Congress St at Northern Ave&lt;/div&gt;`)[0];
#                 popup_8bfa65e37865cfa6a84ec96cdd82682a.setContent(html_7124bbce359c82e3521328a9cc3b7e34);
#
#
#
#         marker_ecdf3f2ddbd36cc8e8d8a029639b13ce.bindPopup(popup_8bfa65e37865cfa6a84ec96cdd82682a)
#         ;
#
#
#
#
#             var marker_e25b9de06be308956c19bd46db31adeb = L.marker(
#                 [42.373268, -71.118579],
#                 {}
#             ).addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var icon_05a07ba48f1e6446bcd4a830f3cd1eb1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e25b9de06be308956c19bd46db31adeb.setIcon(icon_05a07ba48f1e6446bcd4a830f3cd1eb1);
#
#
#         var popup_d56b18081ec4de3257eb430aea5fcfee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bfcc666ffe6265488a1a13aac709c52 = $(`&lt;div id=&quot;html_5bfcc666ffe6265488a1a13aac709c52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harvard Square at Mass Ave/ Dunster&lt;/div&gt;`)[0];
#                 popup_d56b18081ec4de3257eb430aea5fcfee.setContent(html_5bfcc666ffe6265488a1a13aac709c52);
#
#
#
#         marker_e25b9de06be308956c19bd46db31adeb.bindPopup(popup_d56b18081ec4de3257eb430aea5fcfee)
#         ;
#
#
#
#
#             var marker_95f0595cf545c4280a82aa90ddf439a9 = L.marker(
#                 [42.373231, -71.120886],
#                 {}
#             ).addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var icon_32a32d553c0a093baa2d3e81da06e725 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_95f0595cf545c4280a82aa90ddf439a9.setIcon(icon_32a32d553c0a093baa2d3e81da06e725);
#
#
#         var popup_daf29312c2e3b110d5b4a07d88cd07fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44808351618eb1676fcaaf2960e4552c = $(`&lt;div id=&quot;html_44808351618eb1676fcaaf2960e4552c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harvard Square at Brattle St / Eliot St&lt;/div&gt;`)[0];
#                 popup_daf29312c2e3b110d5b4a07d88cd07fc.setContent(html_44808351618eb1676fcaaf2960e4552c);
#
#
#
#         marker_95f0595cf545c4280a82aa90ddf439a9.bindPopup(popup_daf29312c2e3b110d5b4a07d88cd07fc)
#         ;
#
#
#
#
#             var marker_ed6053eff3180e58b1a0dd31bc0f419e = L.marker(
#                 [42.338629, -71.1065],
#                 {}
#             ).addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var icon_7ca2f0afb7b9c376b340353e3edd9951 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quo

# %% [markdown]
# So this is nice, but a little context-less. How well do these stations serve the general population of Boston?
#
# Answering this is a 2 step process. I'll need to overlay my existing map with a choropleth of boston zip codes (the most granular area data I can get for population numbers). So I'll need shape data and population data at the zip code granularity.
#
# Shapefiles are easily accessible from [Mass.gov](https://www.mass.gov/info-details/massgis-data-zip-codes-5-digit-from-here-navteq#downloads-) and population data broken down by zip code is sourced from [Cubit](https://www.massachusetts-demographics.com/zip_codes_by_population).

# %%
# read zip data
# excel dataset so it'll be the worst format conceived for no reason.
zip_pop = pd.read_excel("data/mass_population_zip_2024.xlsx", header=5, dtype='str')[['Massachusetts', 7001399]]

# rename columns
zip_pop.columns = ['zip_code', 'population']

# fix population dtype
zip_pop.population = pd.to_numeric(zip_pop.population)

# %%
zip_pop.head(2)
# Out:
#   zip_code  population
# 0    01001       16045
# 1    01002       22992

# %%
zip_pop.dtypes
# Out:
# zip_code      object
# population     int64
# dtype: object

# %%
# read shapefiles
shps = gpd.read_file("data/zip_shapefiles/ZIPCODES_NT_POLY.shp")
shps.head(2)
# Out:
#   POSTCODE           PC_NAME     PC_TYPE           PA_NAME PA_FIPS  \
# 0    02360          PLYMOUTH  NON UNIQUE          PLYMOUTH   54275
# 1    01230  GREAT BARRINGTON  NON UNIQUE  GREAT BARRINGTON   26780
#
#                    CITY_TOWN     COUNTY   AREA_SQMI    SHAPE_AREA  \
# 0          PLYMOUTH, TOWN OF   PLYMOUTH  103.140309  2.671322e+08
# 1  GREAT BARRINGTON, TOWN OF  BERKSHIRE   96.726569  2.505207e+08
#
#        SHAPE_LEN                                           geometry
# 0  108508.650013  MULTIPOLYGON (((267077.975 859381.793, 267123....
# 1  131086.916737  POLYGON ((43036.16 891528.799, 44309.248 89151...

# %%
# join on postcode
# ensure geodataframe is left dataset
choro_df = shps.merge(zip_pop, left_on='POSTCODE', right_on='zip_code', how = 'left')
choro_df = choro_df[['POSTCODE', 'zip_code', 'population', 'geometry']].dropna()
choro_df['POSTCODE'] = choro_df['POSTCODE'].astype('str')
choro_df.dtypes
# Out:
# POSTCODE        object
# zip_code        object
# population     float64
# geometry      geometry
# dtype: object

# %% [markdown]
# Now we can overlay the existing map of bike stops with the population data

# %%
# make copy of station_map
pop_map = station_map

# %%
folium.Choropleth(
    geo_data = choro_df,
    name = 'choropleth',
    data = choro_df,
    columns = ['population', 'zip_code'],
    key_on="feature.properties.zip_code",
    fill_color="YlGn"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[268], line 1
# ----> 1 folium.Choropleth(
#       2     geo_data = choro_df,
#       3     name = 'choropleth',
#       4     data = choro_df,
#       5     columns = ['population', 'zip_code'],
#       6     key_on="feature.properties.zip_code",
#       7     fill_color="YlGn"
#       8 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/folium/features.py:1545, in Choropleth.__init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1543 if color_data is not None and key_on is not None:
#    1544     real_values = np.array(list(color_data.values()))
# -> 1545     real_values = real_values[~np.isnan(real_values)]
#    1546     if use_jenks:
#    1547         from jenkspy import jenks_breaks
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
pop_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6615f31586ec067cfc1981a53c976f02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6615f31586ec067cfc1981a53c976f02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6615f31586ec067cfc1981a53c976f02 = L.map(
#                 &quot;map_6615f31586ec067cfc1981a53c976f02&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f06fdacb1ba4fe2fbfd055b4b04f3c46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f06fdacb1ba4fe2fbfd055b4b04f3c46.addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var marker_ecdf3f2ddbd36cc8e8d8a029639b13ce = L.marker(
#                 [42.3481, -71.03764],
#                 {}
#             ).addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var icon_eff453b1f7cf99b1da9d37b94b02b4a5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ecdf3f2ddbd36cc8e8d8a029639b13ce.setIcon(icon_eff453b1f7cf99b1da9d37b94b02b4a5);
#
#
#         var popup_8bfa65e37865cfa6a84ec96cdd82682a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7124bbce359c82e3521328a9cc3b7e34 = $(`&lt;div id=&quot;html_7124bbce359c82e3521328a9cc3b7e34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Congress St at Northern Ave&lt;/div&gt;`)[0];
#                 popup_8bfa65e37865cfa6a84ec96cdd82682a.setContent(html_7124bbce359c82e3521328a9cc3b7e34);
#
#
#
#         marker_ecdf3f2ddbd36cc8e8d8a029639b13ce.bindPopup(popup_8bfa65e37865cfa6a84ec96cdd82682a)
#         ;
#
#
#
#
#             var marker_e25b9de06be308956c19bd46db31adeb = L.marker(
#                 [42.373268, -71.118579],
#                 {}
#             ).addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var icon_05a07ba48f1e6446bcd4a830f3cd1eb1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e25b9de06be308956c19bd46db31adeb.setIcon(icon_05a07ba48f1e6446bcd4a830f3cd1eb1);
#
#
#         var popup_d56b18081ec4de3257eb430aea5fcfee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bfcc666ffe6265488a1a13aac709c52 = $(`&lt;div id=&quot;html_5bfcc666ffe6265488a1a13aac709c52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harvard Square at Mass Ave/ Dunster&lt;/div&gt;`)[0];
#                 popup_d56b18081ec4de3257eb430aea5fcfee.setContent(html_5bfcc666ffe6265488a1a13aac709c52);
#
#
#
#         marker_e25b9de06be308956c19bd46db31adeb.bindPopup(popup_d56b18081ec4de3257eb430aea5fcfee)
#         ;
#
#
#
#
#             var marker_95f0595cf545c4280a82aa90ddf439a9 = L.marker(
#                 [42.373231, -71.120886],
#                 {}
#             ).addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var icon_32a32d553c0a093baa2d3e81da06e725 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_95f0595cf545c4280a82aa90ddf439a9.setIcon(icon_32a32d553c0a093baa2d3e81da06e725);
#
#
#         var popup_daf29312c2e3b110d5b4a07d88cd07fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44808351618eb1676fcaaf2960e4552c = $(`&lt;div id=&quot;html_44808351618eb1676fcaaf2960e4552c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harvard Square at Brattle St / Eliot St&lt;/div&gt;`)[0];
#                 popup_daf29312c2e3b110d5b4a07d88cd07fc.setContent(html_44808351618eb1676fcaaf2960e4552c);
#
#
#
#         marker_95f0595cf545c4280a82aa90ddf439a9.bindPopup(popup_daf29312c2e3b110d5b4a07d88cd07fc)
#         ;
#
#
#
#
#             var marker_ed6053eff3180e58b1a0dd31bc0f419e = L.marker(
#                 [42.338629, -71.1065],
#                 {}
#             ).addTo(map_6615f31586ec067cfc1981a53c976f02);
#
#
#             var icon_7ca2f0afb7b9c376b340353e3edd9951 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quo
